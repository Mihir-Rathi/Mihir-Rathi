# %% [markdown]
# ## task-1

# %% [markdown]
# ### t1.py

# %%
import pandas as pd
import numpy as np

temp_value=np.array([32.5, 34.2, 31.8, 35.6, 33.1, 30.4, 29.9])
day=np.array(["Monday","Tuesday","Wedneday","Thursday",    "Friday", "Saturday", "Sunday"])

temps=pd.Series(temp_value,index=day)

print("Temperature Series:\n",temps)

hottest=temps.idxmax()
coldest=temps.idxmin()

print("\nHottest Day:", hottest)
print("Temperature:", temps[hottest])

print("\nColdest Day:", coldest)
print("Temperature:", temps[coldest])
# Out:
# Temperature Series:
#  Monday      32.5
# Tuesday     34.2
# Wedneday    31.8
# Thursday    35.6
# Friday      33.1
# Saturday    30.4
# Sunday      29.9
# dtype: float64
#
# Hottest Day: Thursday
# Temperature: 35.6
#
# Coldest Day: Sunday
# Temperature: 29.9

# %% [markdown]
# ### t2.py

# %%
import pandas as pd

s1 = pd.Series([10, 20, 30], index=['A', 'B', 'C'])
s2 = pd.Series([1, 2, 3], index=['B', 'C', 'D'])

print("Series 1:\n",s1)
print("\nSeries 2:\n",s2)

result = s1 + s2
print("\nAddition:\n",result)

resultfill = s1.add(s2, fill_value=0)
print("\nAddition (fill_value=0):\n",resultfill)
# Out:
# Series 1:
#  A    10
# B    20
# C    30
# dtype: int64
#
# Series 2:
#  B    1
# C    2
# D    3
# dtype: int64
#
# Addition:
#  A     NaN
# B    21.0
# C    32.0
# D     NaN
# dtype: float64
#
# Addition (fill_value=0):
#  A    10.0
# B    21.0
# C    32.0
# D     3.0
# dtype: float64

# %% [markdown]
# ### t3.py

# %%
import pandas as pd
import numpy as np

n=np.random.randint(1,100,7)

s=pd.Series(n)
print("Series:\n",s)

mn=s.mean()
print("Mean Value:",mn)

mask=s>mn

print("Mask:\n",mask)

filterV=s[mask]
print("Values above Mean:\n",filterV)
# Out:
# Series:
#  0    17
# 1     4
# 2     4
# 3    79
# 4    15
# 5    29
# 6    10
# dtype: int32
# Mean Value: 22.571428571428573
# Mask:
#  0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5     True
# 6    False
# dtype: bool
# Values above Mean:
#  3    79
# 5    29
# dtype: int32

# %% [markdown]
# ## task-2

# %% [markdown]
# ### t1.py

# %%
import pandas as pd

df = pd.DataFrame({
    "Name": ["Mihir", "Aryan", "Vidhan", "Harsh", "Devarsh"],
    "Age": [19, 18, 20, 18, 19],
    "Math": [100, 90, 88, 88, 76],
    "Science": [98, 81, 75, 89, 80],
    "English": [88, 84, 79, 91, 77]
},index=[1,2,3,4,5])

df["Total"] = df["Math"] + df["Science"] + df["English"]

print(df)
# Out:
#       Name  Age  Math  Science  English  Total
# 1    Mihir   19   100       98       88    286
# 2    Aryan   18    90       81       84    255
# 3   Vidhan   20    88       75       79    242
# 4    Harsh   18    88       89       91    268
# 5  Devarsh   19    76       80       77    233

# %% [markdown]
# ### t2.py

# %%
import seaborn as sns
import pandas as pd

df = sns.load_dataset("titanic")

print("Shape of dataset:",df.shape)

print("Data Types:\n",df.dtypes)

print("Missing Values Per Column:\n",df.isnull().sum())
# Out:
# Shape of dataset: (891, 15)
# Data Types:
#  survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object
# Missing Values Per Column:
#  survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %% [markdown]
# ### t3.py

# %%
import seaborn as sns
import pandas as pd

df = sns.load_dataset("titanic")

desc = df.describe()
print("Describe Output:\n",desc)

highestcol = desc.loc["std"].idxmax()
highestV = desc.loc["std"].max()

print("\nColumn with highest standard deviation:",highestcol,"=",highestV)

skewV = df.skew(numeric_only=True)

print("\nSkewness:\n",skewV)

skewedcol = skewV.abs().idxmax()
skewedV = skewV[skewedcol]

print("\nMost skewed distribution:",skewedcol, "=", skewedV)
# Out:
# Describe Output:
#           survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200
#
# Column with highest standard deviation: fare = 49.6934285971809
#
# Skewness:
#  survived      0.478523
# pclass       -0.630548
# age           0.389108
# sibsp         3.695352
# parch         2.749117
# fare          4.787317
# adult_male   -0.420431
# alone        -0.420431
# dtype: float64
#
# Most skewed distribution: fare = 4.787316519674893

# %% [markdown]
# ### t4.py

# %%
import pandas as pd

def df_summary(df):
    print("Shape of DataFrame:",df.shape)

    print("\nColumn Names:",df.columns.tolist())
    
    print("\nData Types:\n",df.dtypes)

    print("\nNull Values Per Column:\n",df.isnull().sum())

    print("\nFirst 3 Rows:\n",df.head(3))


data = {
    "Name": ["Mihir", "Vidhan", "Aryan"],
    "Age": [19,20, None],
    "Marks": [95, 90, 88]
}

df = pd.DataFrame(data)

df_summary(df)
# Out:
# Shape of DataFrame: (3, 3)
#
# Column Names: ['Name', 'Age', 'Marks']
#
# Data Types:
#  Name      object
# Age      float64
# Marks      int64
# dtype: object
#
# Null Values Per Column:
#  Name     0
# Age      1
# Marks    0
# dtype: int64
#
# First 3 Rows:
#       Name   Age  Marks
# 0   Mihir  19.0     95
# 1  Vidhan  20.0     90
# 2   Aryan   NaN     88

# %% [markdown]
# ## task-3

# %% [markdown]
# ### t1.py

# %%
import seaborn as sns

df = sns.load_dataset("titanic")

result = df.loc[10:20, ["age", "sex", "fare", "survived"]]

print(result)
# Out:
#      age     sex     fare  survived
# 10   4.0  female  16.7000         1
# 11  58.0  female  26.5500         1
# 12  20.0    male   8.0500         0
# 13  39.0    male  31.2750         0
# 14  14.0  female   7.8542         0
# 15  55.0  female  16.0000         1
# 16   2.0    male  29.1250         0
# 17   NaN    male  13.0000         1
# 18  31.0  female  18.0000         0
# 19   NaN  female   7.2250         1
# 20  35.0    male  26.0000         0

# %% [markdown]
# ### t2.py

# %%
import seaborn as sns

df = sns.load_dataset("titanic")

result = df.iloc[-5:, -3:]

print(result)
# Out:
#      embark_town alive  alone
# 886  Southampton    no   True
# 887  Southampton   yes   True
# 888  Southampton    no  False
# 889    Cherbourg   yes   True
# 890   Queenstown    no   True

# %% [markdown]
# ### t3.py

# %%
import seaborn as sns

df = sns.load_dataset("titanic")

filtered = df[
    (df["sex"] == "female") &
    (df["class"] == "First") &
    (df["survived"] == 1)
]
print("Filter Data:\n",filtered)
print("Count:", filtered.shape[0])
print("Average Fare:", filtered["fare"].mean())
# Out:
# Filter Data:
#       survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 1           1       1  female  38.0      1      0   71.2833        C  First
# 3           1       1  female  35.0      1      0   53.1000        S  First
# 11          1       1  female  58.0      0      0   26.5500        S  First
# 31          1       1  female   NaN      1      0  146.5208        C  First
# 52          1       1  female  49.0      1      0   76.7292        C  First
# ..        ...     ...     ...   ...    ...    ...       ...      ...    ...
# 856         1       1  female  45.0      1      1  164.8667        S  First
# 862         1       1  female  48.0      0      0   25.9292        S  First
# 871         1       1  female  47.0      1      1   52.5542        S  First
# 879         1       1  female  56.0      0      1   83.1583        C  First
# 887         1       1  female  19.0      0      0   30.0000        S  First
#
#        who  adult_male deck  embark_town alive  alone
# 1    woman       False    C    Cherbourg   yes  False
# 3    woman       False    C  Southampton   yes  False
# 11   woman       False    C  Southampton   yes   True
# 31   woman       False    B    Cherbourg   yes  False
# 52   woman       False    D    Cherbourg   yes  False
# ..     ...         ...  ...          ...   ...    ...
# 856  woman       False  NaN  Southampton   yes  False
# 862  woman       False    D  Southampton   yes   True
# 871  woman       False    D  Southampton   yes  False
# 879  woman       False    C    Cherbourg   yes  False
# 887  woman       False    B  Southampton   yes   True
#
# [91 rows x 15 columns]
# Count: 91
# Average Fare: 105.97815934065933

# %% [markdown]
# ### t4.py

# %%
import seaborn as sns

df = sns.load_dataset("titanic")

result = df.query("fare > 200 or (pclass == 1 and age < 10)")
print(result)

print("\nNumber of passengers:", result.shape[0])
# Out:
#      survived  pclass     sex    age  sibsp  parch      fare embarked  class  \
# 27          0       1    male  19.00      3      2  263.0000        S  First
# 88          1       1  female  23.00      3      2  263.0000        S  First
# 118         0       1    male  24.00      0      1  247.5208        C  First
# 258         1       1  female  35.00      0      0  512.3292        C  First
# 297         0       1  female   2.00      1      2  151.5500        S  First
# 299         1       1  female  50.00      0      1  247.5208        C  First
# 305         1       1    male   0.92      1      2  151.5500        S  First
# 311         1       1  female  18.00      2      2  262.3750        C  First
# 341         1       1  female  24.00      3      2  263.0000        S  First
# 377         0       1    male  27.00      0      2  211.5000        C  First
# 380         1       1  female  42.00      0      0  227.5250        C  First
# 438         0       1    male  64.00      1      4  263.0000        S  First
# 445         1       1    male   4.00      0      2   81.8583        S  First
# 527         0       1    male    NaN      0      0  221.7792        S  First
# 557         0       1    male    NaN      0      0  227.5250        C  First
# 679         1       1    male  36.00      0      1  512.3292        C  First
# 689         1       1  female  15.00      0      1  211.3375        S  First
# 700         1       1  female  18.00      1      0  227.5250        C  First
# 716         1       1  female  38.00      0      0  227.5250        C  First
# 730         1       1  female  29.00      0      0  211.3375        S  First
# 737         1       1    male  35.00      0      0  512.3292        C  First
# 742         1       1  female  21.00      2      2  262.3750        C  First
# 779         1       1  female  43.00      0      1  211.3375        S  First
#
#        who  adult_male deck  embark_town alive  alone
# 27     man        True    C  Southampton    no  False
# 88   woman       False    C  Southampton   yes  False
# 118    man        True    B    Cherbourg    no  False
# 258  woman       False  NaN    Cherbourg   yes   True
# 297  child       False    C  Southampton    no  False
# 299  woman       False    B    Cherbourg   yes  False
# 305  child       False    C  Southampton   yes  False
# 311  woman       False    B    Cherbourg   yes  False
# 341  woman       False    C  Southampton   yes  False
# 377    man        True    C    Cherbourg    no  False
# 380  woman       False  NaN    Cherbourg   yes   True
# 438    man        True    C  Southampton    no  False
# 445  child       False    A  Southampton   yes  False
# 527    man        True    C  Southampton    no   True
# 557    man        True  NaN    Cherbourg    no   True
# 679    man        True    B    Cherbourg   yes  False
# 689  child       False    B  Southampton   yes  False
# 700  woman       False    C    Cherbourg   yes  False
# 716  woman       False    C    Cherbourg   yes   True
# 730  woman       False    B  Southampton   yes   True
# 737    man        True    B    Cherbourg   yes   True
# 742  woman       False    B    Cherbourg   yes  False
# 779  woman       False    B  Southampton   yes  False
#
# Number of passengers: 23

# %% [markdown]
# ### t5.py

# %%
import pandas as pd
import numpy as np

n=np.random.randint(0,101,(6,4))
df = pd.DataFrame(
    n,
    columns=["Math", "Physics", "Chemistry", "Computer"],
    index=[1, 2, 3, 4, 5, 6]
)

result = df[(df > 60).all(axis=1)]

print(result)
# Out:
# Empty DataFrame
# Columns: [Math, Physics, Chemistry, Computer]
# Index: []

# %% [markdown]
# ## task-4

# %% [markdown]
# ### t1.py

# %%
import seaborn as sns

df = sns.load_dataset("titanic")

missing = (df.isnull().sum() / len(df)) * 100

print("Missing Percentage Per Column")
print(missing)

dropcols = missing[missing > 50].index

print("\nColumns(>50% Missing)")
print(dropcols)

df = df.drop(columns=dropcols)

print("\nRemaining Columns")
print(df.columns)

df["age"] = df["age"].fillna(
    df.groupby("pclass")["age"].transform("median")
)

print("\nMissing Values After Filling Age")
print(df.isnull().sum())

print("\nUpdated DataFrame")
print(df.head())
# Out:
# Missing Percentage Per Column
# survived        0.000000
# pclass          0.000000
# sex             0.000000
# age            19.865320
# sibsp           0.000000
# parch           0.000000
# fare            0.000000
# embarked        0.224467
# class           0.000000
# who             0.000000
# adult_male      0.000000
# deck           77.216611
# embark_town     0.224467
# alive           0.000000
# alone           0.000000
# dtype: float64
#
# Columns(>50% Missing)
# Index(['deck'], dtype='object')
#
# Remaining Columns
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'embark_town', 'alive',
#        'alone'],
#       dtype='object')
#
# Missing Values After Filling Age
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       2
# class          0
# who            0
# adult_male     0
# embark_town    2
# alive          0
# alone          0
# dtype: int64
#
# Updated DataFrame
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male  embark_town alive  alone
# 0    man        True  Southampton    no  False
# 1  woman       False    Cherbourg   yes  False
# 2  woman       False  Southampton   yes   True
# 3  woman       False  Southampton   yes  False
# 4    man        True  Southampton    no   True

# %% [markdown]
# ### t2.py

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({
    "A": [10, 20, np.nan, 40, 50],
    "B": [5, np.nan, 15, np.nan, 25],
    "C": [np.nan, 12, 18, 24, 30]
})

print("Original DataFrame")
print(df)

print("\ndropna()")
print(df.dropna())

print("\nfillna(0)")
print(df.fillna(0))

print("\nfillna(mean)")
print(df.fillna(df.mean()))

print("\ninterpolate()")
print(df.interpolate)
# Out:
# Original DataFrame
#       A     B     C
# 0  10.0   5.0   NaN
# 1  20.0   NaN  12.0
# 2   NaN  15.0  18.0
# 3  40.0   NaN  24.0
# 4  50.0  25.0  30.0
#
# dropna()
#       A     B     C
# 4  50.0  25.0  30.0
#
# fillna(0)
#       A     B     C
# 0  10.0   5.0   0.0
# 1  20.0   0.0  12.0
# 2   0.0  15.0  18.0
# 3  40.0   0.0  24.0
# 4  50.0  25.0  30.0
#
# fillna(mean)
#       A     B     C
# 0  10.0   5.0  21.0
# 1  20.0  15.0  12.0
# 2  30.0  15.0  18.0
# 3  40.0  15.0  24.0
# 4  50.0  25.0  30.0
#
# interpolate()
# <bound method NDFrame.interpolate of       A     B     C
# 0  10.0   5.0   NaN
# 1  20.0   NaN  12.0
# 2   NaN  15.0  18.0
# 3  40.0   NaN  24.0
# 4  50.0  25.0  30.0>

# %% [markdown]
# ### t3.py

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({
    "Age": [18, 20, np.nan, 22],
    "Marks": [80, np.nan, 75, 90],
    "City": ["Delhi", np.nan, "Mumbai", "Delhi"],
    "Grade": ["A", "B", np.nan, "A"]
})

print("Original DataFrame")
print(df)

df = df.fillna(df.mean(numeric_only=True))

df = df.fillna(df.mode().iloc[0])

print("\nDataFrame After Filling Nulls")
print(df)
# Out:
# Original DataFrame
#     Age  Marks    City Grade
# 0  18.0   80.0   Delhi     A
# 1  20.0    NaN     NaN     B
# 2   NaN   75.0  Mumbai   NaN
# 3  22.0   90.0   Delhi     A
#
# DataFrame After Filling Nulls
#     Age      Marks    City Grade
# 0  18.0  80.000000   Delhi     A
# 1  20.0  81.666667   Delhi     B
# 2  20.0  75.000000  Mumbai     A
# 3  22.0  90.000000   Delhi     A

# %% [markdown]
# ## task-5

# %% [markdown]
# ### t1.py

# %%
import seaborn as sns
import numpy as np

df = sns.load_dataset("titanic")

df["FamilySize"] = df["sibsp"] + df["parch"] + 1

df["IsAlone"] = np.where(df["FamilySize"] == 1, 1, 0)

df["AgeGroup"] = np.where(
    df["age"] < 18,
    "Child",
    np.where(df["age"] <= 60, "Adult", "Senior")
)

print(df[["sibsp", "parch", "FamilySize", "IsAlone", "age", "AgeGroup"]].head(10))
# Out:
#    sibsp  parch  FamilySize  IsAlone   age AgeGroup
# 0      1      0           2        0  22.0    Adult
# 1      1      0           2        0  38.0    Adult
# 2      0      0           1        1  26.0    Adult
# 3      1      0           2        0  35.0    Adult
# 4      0      0           1        1  35.0    Adult
# 5      0      0           1        1   NaN   Senior
# 6      0      0           1        1  54.0    Adult
# 7      3      1           5        0   2.0    Child
# 8      0      2           3        0  27.0    Adult
# 9      1      0           2        0  14.0    Child

# %% [markdown]
# ### t2.py

# %%
import seaborn as sns

df = sns.load_dataset("titanic")

df = df.rename(columns=str.title)

print("TitleCase Columns")
print(df.columns)

df = df.rename(columns=str.lower)

print("\nLowercase Columns")
print(df.columns)
# Out:
# TitleCase Columns
# Index(['Survived', 'Pclass', 'Sex', 'Age', 'Sibsp', 'Parch', 'Fare',
#        'Embarked', 'Class', 'Who', 'Adult_Male', 'Deck', 'Embark_Town',
#        'Alive', 'Alone'],
#       dtype='object')
#
# Lowercase Columns
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %% [markdown]
# ### t3.py

# %%
import seaborn as sns

df = sns.load_dataset("titanic")

df["fareint"] = df["fare"].astype(int)

print(df[["fare", "fareint"]].head())

df["fareround"] = df["fare"].round().astype(int)

print("\nRounded Fare:")
print(df[["fare", "fareround"]].head())
# Out:
#       fare  fareint
# 0   7.2500        7
# 1  71.2833       71
# 2   7.9250        7
# 3  53.1000       53
# 4   8.0500        8
#
# Rounded Fare:
#       fare  fareround
# 0   7.2500          7
# 1  71.2833         71
# 2   7.9250          8
# 3  53.1000         53
# 4   8.0500          8

# %% [markdown]
# ### t4.py

# %%
import seaborn as sns

df = sns.load_dataset("titanic")

print("Shape Before:", df.shape)

df = df.dropna(axis=1)

print("Shape After:", df.shape)
# Out:
# Shape Before: (891, 15)
# Shape After: (891, 11)

# %% [markdown]
# ## main-task

# %% [markdown]
# ### t1.py

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({
    "Name": ["Mihir", "Vidhan", "Aryan", "Harsh", "Devarsh",
             "Dwip", "Bhumesh", "Bhavya", "Krish", "..."],
    
    "Math": [100, 72, 48, 90, 67, 55, 78, 88, 45, 92],
    
    "Science": [98, 75, 52, 95, 60, 58, 82, 91, 49, 89],
    
    "English": [88, 70, 55, 92, 65, 62, 80, 85, 50, 94],
    
    "History": [95, 68, 45, 89, 70, 57, 76, 90, 40, 96]
})

df["Total"] = df[["Math", "Science", "English", "History"]].sum(axis=1)

df["Average"] = df["Total"] / 4

df["Grade"] = np.where(
    df["Average"] >= 80, "A",
    np.where(
        df["Average"] >= 65, "B",
        np.where(df["Average"] >= 50, "C", "F")
    )
)

filtered = df[
    (df["Average"] > 70) &
    (df[["Math", "Science", "English", "History"]] >= 50).all(axis=1)
]

sorteddf = df.sort_values(by="Average", ascending=False)

print("Original DataFrame")
print(df)

print("\nFiltered Students")
print(filtered)

print("\nSorted by Average (Descending)")
print(sorteddf)
# Out:
# Original DataFrame
#       Name  Math  Science  English  History  Total  Average Grade
# 0    Mihir   100       98       88       95    381    95.25     A
# 1   Vidhan    72       75       70       68    285    71.25     B
# 2    Aryan    48       52       55       45    200    50.00     C
# 3    Harsh    90       95       92       89    366    91.50     A
# 4  Devarsh    67       60       65       70    262    65.50     B
# 5     Dwip    55       58       62       57    232    58.00     C
# 6  Bhumesh    78       82       80       76    316    79.00     B
# 7   Bhavya    88       91       85       90    354    88.50     A
# 8    Krish    45       49       50       40    184    46.00     F
# 9      ...    92       89       94       96    371    92.75     A
#
# Filtered Students
#       Name  Math  Science  English  History  Total  Average Grade
# 0    Mihir   100       98       88       95    381    95.25     A
# 1   Vidhan    72       75       70       68    285    71.25     B
# 3    Harsh    90       95       92       89    366    91.50     A
# 6  Bhumesh    78       82       80       76    316    79.00     B
# 7   Bhavya    88       91       85       90    354    88.50     A
# 9      ...    92       89       94       96    371    92.75     A
#
# Sorted by Average (Descending)
#       Name  Math  Science  English  History  Total  Average Grade
# 0    Mihir   100       98       88       95    381    95.25     A
# 9      ...    92       89       94       96    371    92.75     A
# 3    Harsh    90       95       92       89    366    91.50     A
# 7   Bhavya    88       91       85       90    354    88.50     A
# 6  Bhumesh    78       82       80       76    316    79.00     B
# 1   Vidhan    72       75       70       68    285    71.25     B
# 4  Devarsh    67       60       65       70    262    65.50     B
# 5     Dwip    55       58       62       57    232    58.00     C
# 2    Aryan    48       52       55       45    200    50.00     C
# 8    Krish    45       49       50       40    184    46.00     F

# %% [markdown]
# ### t2.py

# %%
import seaborn as sns
import pandas as pd
import numpy as np

df = sns.load_dataset("titanic")

df["age"] = df["age"].fillna(df["age"].median())

df["embarked"] = df["embarked"].fillna(df["embarked"].mode()[0])

df["embark_town"] = df["embark_town"].fillna(df["embark_town"].mode()[0])

df["deck"] = df["deck"].cat.add_categories("Unknown")

df["deck"] = df["deck"].fillna("Unknown")

df["FamilySize"] = df["sibsp"] + df["parch"] + 1

df["IsAlone"] = np.where(df["FamilySize"] == 1, 1, 0)

childrenS = df[
    (df["age"] < 18) &
    (df["survived"] == 1) &
    (df["pclass"] == 3)
]

womenF = df[
    (df["sex"] == "female") &
    (df["pclass"] == 1)
]

survival = womenF["survived"].mean() * 100

print("Children (<18) Who Survived in 3rd Class")
print(childrenS)

print("\nPercentage of Women in 1st Class Who Survived:")
print(survival)

df.to_csv("titanicclean.csv", index=False)

print("\nCleaned DataFrame exported to titanicclean.csv")
# Out:
# Children (<18) Who Survived in 3rd Class
#      survived  pclass     sex    age  sibsp  parch     fare embarked  class  \
# 10          1       3  female   4.00      1      1  16.7000        S  Third
# 22          1       3  female  15.00      0      0   8.0292        Q  Third
# 39          1       3  female  14.00      1      0  11.2417        C  Third
# 68          1       3  female  17.00      4      2   7.9250        S  Third
# 125         1       3    male  12.00      1      0  11.2417        C  Third
# 156         1       3  female  16.00      0      0   7.7333        Q  Third
# 165         1       3    male   9.00      0      2  20.5250        S  Third
# 172         1       3  female   1.00      1      1  11.1333        S  Third
# 184         1       3  female   4.00      0      2  22.0250        S  Third
# 208         1       3  female  16.00      0      0   7.7500        Q  Third
# 220         1       3    male  16.00      0      0   8.0500        S  Third
# 233         1       3  female   5.00      4      2  31.3875        S  Third
# 261         1       3    male   3.00      4      2  31.3875        S  Third
# 348         1       3    male   3.00      1      1  15.9000        S  Third
# 381         1       3  female   1.00      0      2  15.7417        C  Third
# 448         1       3  female   5.00      2      1  19.2583        C  Third
# 469         1       3  female   0.75      2      1  19.2583        C  Third
# 479         1       3  female   2.00      0      1  12.2875        S  Third
# 489         1       3    male   9.00      1      1  15.9000        S  Third
# 644         1       3  female   0.75      2      1  19.2583        C  Third
# 691         1       3  female   4.00      0      1  13.4167        C  Third
# 751         1       3    male   6.00      0      1  12.4750        S  Third
# 777         1       3  female   5.00      0      0  12.4750        S  Third
# 780         1       3  female  13.00      0      0   7.2292        C  Third
# 788         1       3    male   1.00      1      2  20.5750        S  Third
# 803         1       3    male   0.42      0      1   8.5167        C  Third
# 830         1       3  female  15.00      1      0  14.4542        C  Third
# 869         1       3    male   4.00      1      1  11.1333        S  Third
# 875         1       3  female  15.00      0      0   7.2250        C  Third
#
#        who  adult_male     deck  embark_town alive  alone  FamilySize  IsAlone
# 10   child       False        G  Southampton   yes  False           3        0
# 22   child       False  Unknown   Queenstown   yes   True           1        1
# 39   child       False  Unknown    Cherbourg   yes  False           2        0
# 68   woman       False  Unknown  Southampton   yes  False           7        0
# 125  child       False  Unknown    Cherbourg   yes  False           2        0
# 156  woman       False  Unknown   Queenstown   yes   True           1        1
# 165  child       False  Unknown  Southampton   yes  False           3        0
# 172  child       False  Unknown  Southampton   yes  False           3        0
# 184  child       False  Unknown  Southampton   yes  False           3        0
# 208  woman       False  Unknown   Queenstown   yes   True           1        1
# 220    man        True  Unknown  Southampton   yes   True           1        1
# 233  child       False  Unknown  Southampton   yes  False           7        0
# 261  child       False  Unknown  Southampton   yes  False           7        0
# 348  child       False  Unknown  Southampton   yes  False           3        0
# 381  child       False  Unknown    Cherbourg   yes  False           3        0
# 448  child       False  Unknown    Cherbourg   yes  False           4        0
# 469  child       False  Unknown    Cherbourg   yes  False           4        0
# 479  child       False  Unknown  Southampton   yes  False           2        0
# 489  child       False  Unknown  Southampton   yes  False           3        0
# 644  child       False  Unknown    Cherbourg   yes  False           4        0
# 691  child       False  Unknown    Cherbourg   yes  False           2        0
# 751  child       False        E  Southampton   yes  False           2        0
# 777  child       False  Unknown  Southampton   yes   True           1        1
# 780  child       False  Unknown    Cherbourg   yes   True           1        1
# 788  child       False  Unknown  Southampton   yes  False           4        0
# 803  child       False  Unknown    Cherbourg   yes  False           2        0
# 830  child       False  Unknown    Cherbourg   yes  False           2        0
# 869  child       False  Unknown  Southampton   yes  False           3        0
# 875  child       False  Unknown    Cherbourg   yes   True           1        1
#
# Percentage of Women in 1st Class Who Survived:
# 96.80851063829788
#
# Cleaned DataFrame exported to titanicclean.csv

# %% [markdown]
# ### t3.py

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({
    "Date": pd.date_range("2025-01-01", periods=20),

    "Product": [
        "Laptop", "Phone", "Tablet", "Laptop", "Phone",
        "Tablet", "Laptop", "Phone", "Tablet", "Laptop",
        "Phone", "Tablet", "Laptop", "Phone", "Tablet",
        "Laptop", "Phone", "Tablet", "Laptop", "Phone"
    ],

    "Region": [
        "North", "South", "East", "West", "North",
        "South", "East", "West", "North", "South",
        "East", "West", "North", "South", "East",
        "West", "North", "South", "East", "West"
    ],

    "Units": [
        50, 30, np.nan, 45, 60,
        25, 70, 40, 35, np.nan,
        55, 20, 65, 38, 28,
        80, 42, 33, 75, 50
    ],

    "Price": [
        120, 200, 150, 130, np.nan,
        140, 125, 210, 160, 135,
        205, 145, 128, 215, 155,
        132, 220, 148, 130, np.nan
    ]
})

print("=== Original DataFrame ===")
print(df)

print("\n=== Missing Values ===")
print(df.isnull().sum())

df["Units"] = df["Units"].fillna(df["Units"].mean())

df["Price"] = df["Price"].fillna(df["Price"].mean())

df["Revenue"] = df["Units"] * df["Price"]

high_revenue = df[df["Revenue"] > 5000]

top_products = (
    df.groupby("Product")["Revenue"]
    .sum()
    .sort_values(ascending=False)
    .head(3)
)

print("\n=== Revenue Column Added ===")
print(df)

print("\n=== Revenue > 5000 ===")
print(high_revenue)

print("\n=== Top 3 Products by Total Revenue ===")
print(top_products)

print("\n=== Missing Values After Handling ===")
print(df.isnull().sum())

df.to_csv("sales_clean.csv", index=False)

print("\nData exported to sales_clean.csv")
# Out:
# === Original DataFrame ===
#          Date Product Region  Units  Price
# 0  2025-01-01  Laptop  North   50.0  120.0
# 1  2025-01-02   Phone  South   30.0  200.0
# 2  2025-01-03  Tablet   East    NaN  150.0
# 3  2025-01-04  Laptop   West   45.0  130.0
# 4  2025-01-05   Phone  North   60.0    NaN
# 5  2025-01-06  Tablet  South   25.0  140.0
# 6  2025-01-07  Laptop   East   70.0  125.0
# 7  2025-01-08   Phone   West   40.0  210.0
# 8  2025-01-09  Tablet  North   35.0  160.0
# 9  2025-01-10  Laptop  South    NaN  135.0
# 10 2025-01-11   Phone   East   55.0  205.0
# 11 2025-01-12  Tablet   West   20.0  145.0
# 12 2025-01-13  Laptop  North   65.0  128.0
# 13 2025-01-14   Phone  South   38.0  215.0
# 14 2025-01-15  Tablet   East   28.0  155.0
# 15 2025-01-16  Laptop   West   80.0  132.0
# 16 2025-01-17   Phone  North   42.0  220.0
# 17 2025-01-18  Tablet  South   33.0  148.0
# 18 2025-01-19  Laptop   East   75.0  130.0
# 19 2025-01-20   Phone   West   50.0    NaN
#
# === Missing Values ===
# Date       0
# Product    0
# Region     0
# Units      2
# Price      2
# dtype: int64
#
# === Revenue Column Added ===
#          Date Product Region      Units       Price       Revenue
# 0  2025-01-01  Laptop  North  50.000000  120.000000   6000.000000
# 1  2025-01-02   Phone  South  30.000000  200.000000   6000.000000
# 2  2025-01-03  Tablet   East  46.722222  150.000000   7008.333333
# 3  2025-01-04  Laptop   West  45.000000  130.000000   5850.000000
# 4  2025-01-05   Phone  North  60.000000  158.222222   9493.333333
# 5  2025-01-06  Tablet  South  25.000000  140.000000   3500.000000
# 6  2025-01-07  Laptop   East  70.000000  125.000000   8750.000000
# 7  2025-01-08   Phone   West  40.000000  210.000000   8400.000000
# 8  2025-01-09  Tablet  North  35.000000  160.000000   5600.000000
# 9  2025-01-10  Laptop  South  46.722222  135.000000   6307.500000
# 10 2025-01-11   Phone   East  55.000000  205.000000  11275.000000
# 11 2025-01-12  Tablet   West  20.000000  145.000000   2900.000000
# 12 2025-01-13  Laptop  North  65.000000  128.000000   8320.000000
# 13 2025-01-14   Phone  South  38.000000  215.000000   8170.000000
# 14 2025-01-15  Tablet   East  28.000000  155.000000   4340.000000
# 15 2025-01-16  Laptop   West  80.000000  132.000000  10560.000000
# 16 2025-01-17   Phone  North  42.000000  220.000000   9240.000000
# 17 2025-01-18  Tablet  South  33.000000  148.000000   4884.000000
# 18 2025-01-19  Laptop   East  75.000000  130.000000   9750.000000
# 19 2025-01-20   Phone   West  50.000000  158.222222   7911.111111
#
# === Revenue > 5000 ===
#          Date Product Region      Units       Price       Revenue
# 0  2025-01-01  Laptop  North  50.000000  120.000000   6000.000000
# 1  2025-01-02   Phone  South  30.000000  200.000000   6000.000000
# 2  2025-01-03  Tablet   East  46.722222  150.000000   7008.333333
# 3  2025-01-04  Laptop   West  45.000000  130.000000   5850.000000
# 4  2025-01-05   Phone  North  60.000000  158.222222   9493.333333
# 6  2025-01-07  Laptop   East  70.000000  125.000000   8750.000000
# 7  2025-01-08   Phone   West  40.000000  210.000000   8400.000000
# 8  2025-01-09  Tablet  North  35.000000  160.000000   5600.000000
# 9  2025-01-10  Laptop  South  46.722222  135.000000   6307.500000
# 10 2025-01-11   Phone   East  55.000000  205.000000  11275.000000
# 12 2025-01-13  Laptop  North  65.000000  128.000000   8320.000000
# 13 2025-01-14   Phone  South  38.000000  215.000000   8170.000000
# 15 2025-01-16  Laptop   West  80.000000  132.000000  10560.000000
# 16 2025-01-17   Phone  North  42.000000  220.000000   9240.000000
# 18 2025-01-19  Laptop   East  75.000000  130.000000   9750.000000
# 19 2025-01-20   Phone   West  50.000000  158.222222   7911.111111
#
# === Top 3 Products by Total Revenue ===
# Product
# Phone     60489.444444
# Laptop    55537.500000
# Tablet    28232.333333
# Name: Revenue, dtype: float64
#
# === Missing Values After Handling ===
# Date       0
# Product    0
# Region     0
# Units      0
# Price      0
# Revenue    0
# dtype: int64
#
# Data exported to sales_clean.csv
